# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import MDS
import re

# %%
import spacy
from spacy.lang.en import stop_words

# %%
# Documents
doc = pd.read_csv('edmunds_extraction.csv', header=None)
doc
# Out:
#                   0           1  \
# 0        wishnhigh1  April 2002
# 1            kd6aw1  April 2002
# 2           fwatson  April 2002
# 3          dave330i  April 2002
# 4     blueguydotcom  April 2002
# ...             ...         ...
# 5145     laurasdada    May 2006
# 5146    ivorypearlg    May 2006
# 5147          shipo    May 2006
# 5148        dhanley    May 2006
# 5149    ivorypearlg    May 2006
#
#                                                       2
# 0      The problem is that they are HUGE generalizat...
# 1      Have found out that with some of the more pow...
# 2      How does your theory explain English cars? A ...
# 3      "Being that it is an automatic I can enjoy my...
# 4      He did mention "in rush hour traffic." Like t...
# ...                                                 ...
# 5145   I had a '99 300M, loved it. New 300? Well, th...
# 5146   I've been in the 300M and 300C... Much differ...
# 5147   I don't know, maybe it's just me or maybe my ...
# ...

# %%
#pip install nltk

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\TYS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
doc.columns = ["users", "time", "txt"]
doc.head()
# Out:
#            users        time  \
# 0     wishnhigh1  April 2002
# 1         kd6aw1  April 2002
# 2        fwatson  April 2002
# 3       dave330i  April 2002
# 4  blueguydotcom  April 2002
#
#                                                  txt
# 0   The problem is that they are HUGE generalizat...
# 1   Have found out that with some of the more pow...
# 2   How does your theory explain English cars? A ...
# 3   "Being that it is an automatic I can enjoy my...
# 4   He did mention "in rush hour traffic." Like t...

# %%
# tokenize and lower case
import nltk
from nltk import word_tokenize

tokens = []
for i in range(len(doc)):
    tokens.append(word_tokenize(doc.loc[i,'txt'].lower()))
doc['txt_tokenized'] = tokens

# %%
doc.head()
# Out:
#            users        time  \
# 0     wishnhigh1  April 2002
# 1         kd6aw1  April 2002
# 2        fwatson  April 2002
# 3       dave330i  April 2002
# 4  blueguydotcom  April 2002
#
#                                                  txt  \
# 0   The problem is that they are HUGE generalizat...
# 1   Have found out that with some of the more pow...
# 2   How does your theory explain English cars? A ...
# 3   "Being that it is an automatic I can enjoy my...
# 4   He did mention "in rush hour traffic." Like t...
#
#                                        txt_tokenized
# 0  [the, problem, is, that, they, are, huge, gene...
# 1  [have, found, out, that, with, some, of, the, ...
# 2  [how, does, your, theory, explain, english, ca...
# 3  [``, being, that, it, is, an, automatic, i, ca...
# 4  [he, did, mention, ``, in, rush, hour, traffic...

# %%
attributes = pd.read_csv('Attributes.csv', header=0)
attributes
# Out:
#            Feature      Mapping
# 0           luxury      comfort
# 1             room      comfort
# 2             tall      comfort
# 3         interior      comfort
# 4        interiors      comfort
# ..             ...          ...
# 104    replacement  maintenance
# 105     suspension  performance
# 106   transmission  performance
# 107  transmissions  performance
# 108            rpm  performance
#
# [109 rows x 2 columns]

# %%
new_attributes = [
    {"Feature": "acceleration", "Mapping": "performance"},
    {"Feature": "horsepower", "Mapping": "performance"},
    {"Feature": "torque", "Mapping": "performance"},
    {"Feature": "top speed", "Mapping": "performance"},
    {"Feature": "handling", "Mapping": "performance"},
    {"Feature": "braking", "Mapping": "safety"},
    {"Feature": "airbags", "Mapping": "safety"},
    {"Feature": "traction control", "Mapping": "safety"},
    {"Feature": "ABS", "Mapping": "safety"},
    {"Feature": "crash test rating", "Mapping": "safety"},
    {"Feature": "aerodynamics", "Mapping": "design"},
    {"Feature": "body style", "Mapping": "design"},
    {"Feature": "interior materials", "Mapping": "design"},
    {"Feature": "exterior finish", "Mapping": "design"},
    {"Feature": "fuel efficiency", "Mapping": "efficiency"},
    {"Feature": "emissions", "Mapping": "efficiency"},
    {"Feature": "range", "Mapping": "efficiency"},
    {"Feature": "charging time", "Mapping": "efficiency"},
    {"Feature": "infotainment system", "Mapping": "technology"},
    {"Feature": "connectivity", "Mapping": "technology"},
    {"Feature": "driver assistance", "Mapping": "technology"},
    {"Feature": "navigation system", "Mapping": "technology"},
    {"Feature": "electric motor", "Mapping": "technology"}
    
]

# %%
# Convert the list of dictionaries to a DataFrame
new_attributes_df = pd.DataFrame(new_attributes)

# Append the new attributes to the existing DataFrame
expanded_attributes_df = pd.concat([attributes, new_attributes_df], ignore_index=True)

# Display the first few rows of the expanded DataFrame
expanded_attributes_df.head()
# Out:
#      Feature  Mapping
# 0     luxury  comfort
# 1       room  comfort
# 2       tall  comfort
# 3   interior  comfort
# 4  interiors  comfort

# %%
attributes = expanded_attributes_df

# %%
features = [feature.lower() for feature in attributes['Feature'].tolist()]
mapping = [map_item.lower() for map_item in attributes['Mapping'].tolist()]

# %%
mapping_dict = {}

for i in range(len(features)):
    mapping_dict[features[i]] = mapping[i]

# %% [markdown]
# ### Remove stopwords/punctuations

# %%
stop_words = list(stop_words.STOP_WORDS)
punc = ['.',',','!','?',';',':',"'","''", '"','``','(',')','[',']','{','}','-','...','–', '/','\\','&','%','$','#','@','+',
    '*','=','>','<','|','~','_']

# %%
def remove_stopwords(lst):
    tokens_wo_stopwords = []
    for word in lst:
        if word not in stop_words:
            if word not in punc:
                tokens_wo_stopwords.append(word)
    return tokens_wo_stopwords

# %% [markdown]
# ### Replace feature words into to mapping words

# %%
def features_to_mapping(lst):
    
    new_lst = []
    for word in lst:
        new_lst.append(mapping_dict.get(word, word))
        
    return new_lst

# %%
doc["txt_token_mapped"] = doc["txt_tokenized"].apply(features_to_mapping)

# %%
doc["txt_wo_stopwords"] = doc["txt_token_mapped"].apply(remove_stopwords)

# %% [markdown]
# ### Attribute Frequency

# %%
txt_combined = []

for i in range(len(doc)):
    txt_combined.extend(doc.loc[i, "txt_wo_stopwords"])

# %%
freq_dist = dict(nltk.FreqDist(word for word in txt_combined))
freq_dist
# Out:
# {'problem': 197,
#  'huge': 69,
#  'generalizations': 4,
#  'talking': 203,
#  'japanese': 196,
#  'exclusivly': 1,
#  'honda': 229,
#  'toyota': 131,
#  'subaru': 140,
#  'mazda': 76,
#  'isuzu': 4,
#  'mitsubishi': 19,
#  'daihatsu': 2,
#  'suzuki': 12,
#  'far': 290,
#  'makes': 289,
#  'culture': 5,
#  'american': 139,
#  'european': 88,
#  'capable': 46,
#  'having': 193,
#  'higher': 134,
#  'quality': 205,
#  '70': 58,
#  'cars': 1963,
#  'help': 99,
#  'generalization': 5,
#  'stop': 108,
#  'brands': 89,
#  'nations': 1,
#  'found': 144,
#  'powerful': 93,
#  'like': 1835,
#  'g35': 1327,
#  'corvette': 40,
#  'difference': 315,
#  'performance': 8905,
#  'practical': 25,
#  'standpoint': 12,
#  'issue': 145,
#  'faster': 180,
#  'dream': 17,
#  'driving': 774,
#  'killing': 4,
#  'getting': 324,
#  'tickets': 3,
#  'time': 603,
#  'love': 268,
#  'enjoy': 126,
#  'coffee': 6,
#  'shave': 4,
#  'talk': 90,
#  'cel': 3,
#  'phone': 34,
#  'hug': 5,
#  'wife': 146,
# ...

# %%
features_dist = {}
features_list = attributes['Mapping'].tolist()

for feature in features_list:
    features_dist[feature] = freq_dist.get(feature, None)

# %%
features_dist
# Out:
# {'comfort': 1999,
#  'console': 491,
#  'efficiency': 1083,
#  'performance': 8905,
#  'safety': 983,
#  'styling': 715,
#  'maintenance': 371,
#  'design': 146,
#  'technology': 43}

# %%
top_5_features_dist = dict(sorted(features_dist.items(), key=lambda item: item[1], reverse=True)[:9])
top_5_features_dist
# Out:
# {'performance': 8905,
#  'comfort': 1999,
#  'efficiency': 1083,
#  'safety': 983,
#  'styling': 715,
#  'console': 491,
#  'maintenance': 371,
#  'design': 146,
#  'technology': 43}

# %%
# Convert to DataFrame with keys as a separate column
top_5_features_dist = pd.DataFrame(list(top_5_features_dist.items()), columns=['Feature', 'Frequency'])
top_5_features_dist
# Out:
#        Feature  Frequency
# 0  performance       8905
# 1      comfort       1999
# 2   efficiency       1083
# 3       safety        983
# 4      styling        715
# 5      console        491
# 6  maintenance        371
# 7       design        146
# 8   technology         43

# %% [markdown]
# ### Lift Matrix

# %%
brand = pd.read_csv('top10_brands.csv', header=0)

# %%
top_5_brands = brand[:5]
top_5_brands
# Out:
#       brand
# 0       bmw
# 1     acura
# 2  infiniti
# 3      audi
# 4  mercedes

# %%
pairs = []
for i in range(len(top_5_brands['brand'])):
    for j in range(i + 1,len(top_5_features_dist['Feature'])):
        pair = (top_5_brands['brand'][i], top_5_features_dist['Feature'][j])
        pairs.append(pair)

# %%
# calculate presence of each pair in txt
pairs_freq_dict = {}
for pair in pairs:
    pairs_freq_dict[pair] = 0

# %%
txt_wo_stopwords_lst = doc["txt_wo_stopwords"].tolist()

for key, value in pairs_freq_dict.items():
    brand = key[0]
    feature = key[1]
    for lst in txt_wo_stopwords_lst:
        if brand in lst and feature in lst:
            pairs_freq_dict[key] = pairs_freq_dict[key] + 1

pairs_freq_dict
# Out:
# {('bmw', 'comfort'): 319,
#  ('bmw', 'efficiency'): 148,
#  ('bmw', 'safety'): 146,
#  ('bmw', 'styling'): 152,
#  ('bmw', 'console'): 78,
#  ('bmw', 'maintenance'): 97,
#  ('bmw', 'design'): 40,
#  ('bmw', 'technology'): 12,
#  ('acura', 'efficiency'): 40,
#  ('acura', 'safety'): 50,
#  ('acura', 'styling'): 60,
#  ('acura', 'console'): 46,
#  ('acura', 'maintenance'): 24,
#  ('acura', 'design'): 13,
#  ('acura', 'technology'): 7,
#  ('infiniti', 'safety'): 32,
#  ('infiniti', 'styling'): 41,
#  ('infiniti', 'console'): 33,
#  ('infiniti', 'maintenance'): 36,
#  ('infiniti', 'design'): 10,
#  ('infiniti', 'technology'): 4,
#  ('audi', 'styling'): 46,
#  ('audi', 'console'): 23,
#  ('audi', 'maintenance'): 28,
#  ('audi', 'design'): 16,
#  ('audi', 'technology'): 4,
#  ('mercedes', 'console'): 10,
#  ('mercedes', 'maintenance'): 12,
#  ('mercedes', 'design'): 3,
#  ('mercedes', 'technology'): 2}

# %%
top_5_brands_freq = pd.read_csv('top10_brands_frequency.csv', header=0)
top_5_brands_freq = top_5_brands_freq[:5]

# %%
top_5_brands_freq
# Out:
#       brand  frequency
# 0       bmw       4479
# 1     acura       2697
# 2  infiniti       1922
# 3      audi        988
# 4  mercedes        699

# %%
top5_features_dict = top_5_features_dist.set_index('Feature')['Frequency'].to_dict()

top5_brands_dict = top_5_brands_freq.set_index('brand')['frequency'].to_dict()

lift_dict = {}
total_txt = len(doc)  # Replace 'doc' with the actual variable that represents your total document count

for key, value in pairs_freq_dict.items():
    brand, feature = key  # Unpack the key which is a tuple of (brand, feature)
    AB = value
    count_A = top5_brands_dict[brand]  # Get brand count
    count_B = top5_features_dict[feature]  # Get feature count

    # Calculate lift, ensuring that count_A and count_B are not zero
    if count_A > 0 and count_B > 0:
        lift_dict[key] = total_txt * AB / (count_A * count_B)

# %%
lift_dict
# Out:
# {('bmw', 'comfort'): 0.18348647420383557,
#  ('bmw', 'efficiency'): 0.1571301139183018,
#  ('bmw', 'safety'): 0.17077547601477858,
#  ('bmw', 'styling'): 0.2444351808049062,
#  ('bmw', 'console'): 0.18265824356160384,
#  ('bmw', 'maintenance'): 0.3006242368549487,
#  ('bmw', 'design'): 0.3150165001360994,
#  ('bmw', 'technology'): 0.3208772722316547,
#  ('acura', 'efficiency'): 0.07052739081863471,
#  ('acura', 'safety'): 0.09712762494478813,
#  ('acura', 'styling'): 0.16024020473408682,
#  ('acura', 'console'): 0.17889682056022116,
#  ('acura', 'maintenance'): 0.12352748936374348,
#  ('acura', 'design'): 0.17002656426978732,
#  ('acura', 'technology'): 0.3108535754628312,
#  ('infiniti', 'safety'): 0.08722687349880327,
#  ('infiniti', 'styling'): 0.1536496801845397,
#  ('infiniti', 'console'): 0.18008862967335026,
#  ('infiniti', 'maintenance'): 0.260005441322073,
#  ('infiniti', 'design'): 0.1835274328966687,
#  ('infiniti', 'technology'): 0.24925586235268496,
# ...

# %%
# Convert to a list of tuples for DataFrame creation
data = [(brand, attribute, lift) for (brand, attribute), lift in lift_dict.items()]

# Create a DataFrame
lift_df = pd.DataFrame(data, columns=['Brand', 'Attribute', 'Lift'])

# Find the attribute with the highest lift ratio for each brand
strongest_association = lift_df.loc[lift_df.groupby('Brand')['Lift'].idxmax()]

# %%
strongest_association
# Out:
#        Brand    Attribute      Lift
# 14     acura   technology  0.310854
# 24      audi       design  0.571238
# 7        bmw   technology  0.320877
# 18  infiniti  maintenance  0.260005
# 29  mercedes   technology  0.342682

# %%
# Convert to a list of tuples for DataFrame creation
data = [(brand, attribute, lift) for (brand, attribute), lift in lift_dict.items()]

# Create a DataFrame
lift_df = pd.DataFrame(data, columns=['Brand', 'Attribute', 'Lift'])

# Find the attribute with the highest lift ratio for each brand
strongest_association = lift_df.loc[lift_df.groupby('Brand')['Lift'].idxmax()]

# Plotting
fig, ax = plt.subplots(figsize=(6, 4))

# Extract brands and attributes for labeling
brands = strongest_association['Brand']
attributes = strongest_association['Attribute']
lifts = strongest_association['Lift']

# Create bar plot
ax.barh(brands, lifts, color='skyblue', edgecolor='black')
ax.set_xlabel('Lift Ratio')
ax.set_title('Strongest Attribute Association per Car Brand')

# Add attribute labels to the bars
for i, (brand, attribute, lift) in enumerate(strongest_association.values):
    ax.text(lift, i, f' {attribute} ({lift:.2f})', va='center')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### MDS

# %%
# Calculate dissimilarity matrix based on lift
dissimilarity_dict = {}

for key, value in lift_dict.items():
    dissimilarity_dict[key] = 1 / value

dissimilarity_dict
# Out:
# {('bmw', 'comfort'): 5.449992999969565,
#  ('bmw', 'efficiency'): 6.364152453424299,
#  ('bmw', 'safety'): 5.855641707673893,
#  ('bmw', 'styling'): 4.091064128768523,
#  ('bmw', 'console'): 5.47470500373413,
#  ('bmw', 'maintenance'): 3.3264117705935345,
#  ('bmw', 'design'): 3.1744368932038833,
#  ('bmw', 'technology'): 3.1164563106796117,
#  ('acura', 'efficiency'): 14.178888349514562,
#  ('acura', 'safety'): 10.295732038834952,
#  ('acura', 'styling'): 6.240631067961165,
#  ('acura', 'console'): 5.589814267623471,
#  ('acura', 'maintenance'): 8.095364077669903,
#  ('acura', 'design'): 5.881433905899926,
#  ('acura', 'technology'): 3.2169486823855755,
#  ('infiniti', 'safety'): 11.464356796116505,
#  ('infiniti', 'styling'): 6.508311626805589,
#  ('infiniti', 'console'): 5.552821418064137,
#  ('infiniti', 'maintenance'): 3.8460733549083064,
#  ('infiniti', 'design'): 5.448776699029127,
#  ('infiniti', 'technology'): 4.011941747572815,
#  ('audi', 'styling'): 2.9819333051920642,
# ...

# %%
data = [(brand, attribute, 1 / dissimilarity) for (brand, attribute), dissimilarity in dissimilarity_dict.items()]
dissimilarity_df = pd.DataFrame(data, columns=['Brand', 'Attribute', 'Dissimilarity'])


dissimilarity_matrix = dissimilarity_df.pivot(index='Brand', columns='Attribute', values='Dissimilarity').fillna(0)

# %%
dissimilarity_df = dissimilarity_matrix.fillna(0)

# %%
dissimilarity_2d_values = dissimilarity_df.values

# %%
# Perform MDS on the dissimilarity values
# Perform MDS without specifying 'precomputed', treating the rows as points in high-dimensional space
mds = MDS(n_components=2, random_state=42)
mds_fit = mds.fit_transform(dissimilarity_2d_values)

# %%
# Convert the MDS results into a DataFrame
mds_df_values = pd.DataFrame(mds_fit, index=brands, columns=['x', 'y'])

# Plot the MDS results
plt.figure(figsize=(6, 4))
plt.scatter(mds_df_values['x'], mds_df_values['y'])
for brand in brands:
    plt.text(mds_df_values.loc[brand, 'x'], mds_df_values.loc[brand, 'y'], brand)
plt.xlabel('MDS Dimension 1')
plt.ylabel('MDS Dimension 2')
plt.title('MDS (Multidimensional Scaling) of Car Brands based on Attribute Values')
plt.grid(True)
plt.show()

# %% [markdown]
# ###  Initial understanding of the plot
#
# 1. BMW is placed quite far from Audi and Mercedes, suggesting that in terms of the attributes considered, BMW is quite dissimilar to these two.
#
# 2. Acura, Infiniti and Mercedes are relatively close, indicating some similarity in the dataset's context.
#
# 3. The plot does not show inherent clusters, suggesting that the brands are relatively spread out with respect to the attributes considered.
